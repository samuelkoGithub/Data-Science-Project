# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelkoGithub/Data-Science-Project/blob/main/first_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()
plt.plot([1,2,3],[1,2,3])
plt.show()
# Out:
# <div id='c1faf72b-a2df-47a8-8496-1ce73b911207'></div>
# <div id='829852a8-b9aa-48d5-8166-c6213f434521'></div>
# <div id='a4f3ad53-7050-4023-8a73-84797065a941'></div>

# %%
print('Hello World')
# Out:
# Hello World
