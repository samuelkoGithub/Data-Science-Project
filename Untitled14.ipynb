# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelkoGithub/Data-Science-Project/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive, files

# Load the netflix_title.csv from my Google Drive
drive.mount('/content/gdrive')

# The following lines prevent some errors while loading data, delete them from the code and check for yourselves:
# - encoding="latin-1"
# - delimiter=","
df=pd.read_csv('gdrive/My Drive/csv/netflix_titles.csv', delimiter=",", encoding="latin-1", parse_dates=["date_added"], index_col=["show_id"])
# Dataset is ranked according to "show_id" column.

# Display the content of retrieved dataframe - df
df
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# ...

# %%
df.dtypes
# Out:
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
# Data Cleaning
df["date_added"] = df["date_added"].dt.year
df["date_added"].unique()
# Out:
# array([2021., 2020., 2019., 2018., 2017., 2016., 2015., 2014., 2013.,
#        2012., 2011., 2009., 2008.,   nan, 2010.])

# %%
df["date_added"].fillna(0, inplace=True)
df["date_added"] = df["date_added"].astype(int)
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          date_added  release_year rating   duration  \
# show_id
# s1             2021          2020  PG-13     90 min
# ...

# %%
# df[df["date_added"]==0]
df.loc[df["date_added"]==0, ]

# Check NaN values if exist or not?
df.info()

# check for duplicate rows
df.duplicated().sum()

# check for duplicate rows if any
df.duplicated().sum()

df.fillna("No Data", inplace=True)
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8807 non-null   int64
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 825.7+ KB
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# Exploratory data analysis
plt.figure(figsize=(14, 7))
labels=['TV Show', 'Movie']
plt.pie(df['type'].value_counts().sort_values(),labels=labels,explode=[0.1,0.1],
        autopct='%1.2f%%',colors=['yellow','orange'], startangle=90)
plt.title('Type of Netflix Content')
plt.axis('equal')
plt.show()

# Conclusion
# There is much more to dig deep but these can be summarized as general inference.
